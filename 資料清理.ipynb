# %%
import numpy as np
import scipy.stats as stats
import pandas as pd

# 讀取數據並進行分類處理
from google.colab import drive
drive.mount("/content/drive")
product_data = pd.read_csv("/content/drive/My Drive/Colab Notebooks/期末/fitness analysis.csv")
product_data = product_data.dropna() #刪除缺失值
#檢查是否有缺失值
print(product_data.isnull().sum()) 
#利用平均值填補缺失值
product_data = product_data.fillna(product_data.mean())
#檢查是否還有缺失值
print(product_data.isnull().sum())


#刪除不需要的資料
product_data.drop('Timestamp', axis=1, inplace=True)
product_data.drop('Your name ', axis=1, inplace=True)

#改變index名字
new_cols=['Gender','Age','Important_score','Fitness_level','Exercise_frequency','Exercise_barrier','Exercise_form','People_number','Time','Duration_of_time','Healthy_diet','Healthy_diet_barrier','Healthy_score','Recommend_friend','Purchase_equipment','Motivates']
column_reference=pd.DataFrame(new_cols,product_data.columns)
product_data.columns=new_cols

# 改性別Gender，將 'Male' 改為 1，將 'Female' 改為 2
product_data.loc[product_data['Gender'] == 'Male', 'Gender'] = 1
product_data.loc[product_data['Gender'] == 'Female', 'Gender'] = 2
# 改年齡Age，使用正則表達式擷取年齡中的數字部分
product_data['Age'] = product_data['Age'].str.extract(r'(\d+)')
# 將字串轉換為數字
product_data['Age'] = product_data['Age'].astype(int)
# 改運動頻率Exercise_frequency
product_data.loc[product_data['Exercise_frequency'] == 'Never', 'Exercise_frequency'] = '0'
product_data.loc[product_data['Exercise_frequency'] == 'Everyday', 'Exercise_frequency'] = '7'
product_data['Exercise_frequency'] = product_data['Exercise_frequency'].str.extract(r'(\d+)')
product_data['Exercise_frequency'] = product_data['Exercise_frequency'].fillna(0)  # 將缺失值填充為0
product_data['Exercise_frequency'] = product_data['Exercise_frequency'].astype(int)
# 改運動長度Duration_of_time
product_data.loc[product_data['Duration_of_time'] == "I don't really exercise", 'Duration_of_time'] = 0
product_data.loc[product_data['Duration_of_time'] == '30 minutes', 'Duration_of_time'] = 30
product_data.loc[product_data['Duration_of_time'] == '1 hour', 'Duration_of_time'] = 60
product_data.loc[product_data['Duration_of_time'] == '2 hours', 'Duration_of_time'] = 120
product_data.loc[product_data['Duration_of_time'] == '3 hours and above', 'Duration_of_time'] = 180

# 改是否有在吃健康餐Healthy_diet
product_data.loc[product_data['Healthy_diet'] == 'No', 'Healthy_diet'] = 0
product_data.loc[product_data['Healthy_diet'] == 'Yes', 'Healthy_diet'] = 1
product_data.loc[product_data['Healthy_diet'] == 'Not always', 'Healthy_diet'] = 2
# 改是否介紹朋友Recommend_friend
product_data.loc[product_data['Recommend_friend'] == 'No', 'Recommend_friend'] = 0
product_data.loc[product_data['Recommend_friend'] == 'Yes', 'Recommend_friend'] = 1
# 改是否購買健身器材Purchase_equipment
product_data.loc[product_data['Purchase_equipment'] == 'No', 'Purchase_equipment'] = 0
product_data.loc[product_data['Purchase_equipment'] == 'Yes', 'Purchase_equipment'] = 1

#檢視前5筆數據
print(product_data.head(15))

product_data.info()

product_data.to_csv("new_fitness_analysis.csv", index=False) #轉成csv格式
print("數據已儲存!")
# Out:
# Mounted at /content/drive
# Timestamp                                                                                                                0
# Your name                                                                                                                0
# Your gender                                                                                                              0
# Your age                                                                                                                 0
# How important is exercise to you ?                                                                                       0
# How do you describe your current level of fitness ?                                                                      0
# How often do you exercise?                                                                                               0
# What barriers, if any, prevent you from exercising more regularly?           (Please select all that apply)              0
# What form(s) of exercise do you currently participate in ?                        (Please select all that apply)         0
# Do you exercise ___________ ?                                                                                            0
# What time if the day do you prefer to exercise?                                                                          0
# How long do you spend exercising per day ?                                                                               0
# Would you say you eat a healthy balanced diet ?                                                                          0
# What prevents you from eating a healthy balanced diet, If any?                         (Please select all that apply)    0
# How healthy do you consider yourself?                                                                                    0
# Have you ever recommended your friends to follow a fitness routine?                                                      0
# Have you ever purchased a fitness equipment?                                                                             0
# What motivates you to exercise?         (Please select all that applies )                                                0
# dtype: int64
# Timestamp                                                                                                                0
# Your name                                                                                                                0
# Your gender                                                                                                              0
# Your age                                                                                                                 0
# How important is exercise to you ?                                                                                       0
# How do you describe your current level of fitness ?                                                                      0
# How often do you exercise?                                                                                               0
# What barriers, if any, prevent you from exercising more regularly?           (Please select all that apply)              0
# What form(s) of exercise do you currently participate in ?                        (Please select all that apply)         0
# Do you exercise ___________ ?                                                                                            0
# What time if the day do you prefer to exercise?                                                                          0
# How long do you spend exercising per day ?                                                                               0
# Would you say you eat a healthy balanced diet ?                                                                          0
# What prevents you from eating a healthy balanced diet, If any?                         (Please select all that apply)    0
# How healthy do you consider yourself?                                                                                    0
# Have you ever recommended your friends to follow a fitness routine?                                                      0
# Have you ever purchased a fitness equipment?                                                                             0
# What motivates you to exercise?         (Please select all that applies )                                                0
# dtype: int64
#    Gender  Age  Important_score Fitness_level  Exercise_frequency  \
# 0       2   19                2          Good                   0
# 1       2   19                4     Very good                   0
# 2       2   15                3          Good                   1
# 3       2   15                4          Good                   3
# 4       2   19                3         Unfit                   0
# 5       2   40                5       Average                   3
# 6       1   40                3          Good                   1
# 7       2   15                3         Unfit                   0
# 8       1   19                5         Unfit                   3
# 9       1   15                5     Very good                   7
# 10      1   15                4     Very good                   3
# 11      1   19                5         Unfit                   3
# 12      1   15                4         Unfit                   0
# 13      2   15                3       Average                   1
# 14      1   19                5       Average                   1
#
#                                      Exercise_barrier  \
# 0     I don't have enough time;I can't stay motivated
# 1      I don't have enough time;I'll become too tired
# 2                              I can't stay motivated
# 3                            I don't have enough time
# 4                              I can't stay motivated
# 5               I exercise regularly with no barriers
# 6                     I don't really enjoy exercising
# 7   I can't stay motivated;I don't really enjoy ex...
# 8   I don't have enough time;I can't stay motivate...
# 9   I don't have enough time;I exercise regularly ...
# 10                           I don't have enough time
# 11                           I don't have enough time
# 12                             I can't stay motivated
# 13  I don't have enough time;I can't stay motivate...
# 14  I don't have enough time;I'll become too tired...
#
#                              Exercise_form            People_number  \
# 0                  I don't really exercise  I don't really exercise
# 1              Walking or jogging;Swimming             With a group
# 2                       Walking or jogging                    Alone
# 3   Walking or jogging;Gym;Lifting weights                    Alone
# 4                  I don't really exercise  I don't really exercise
# 5                  Walking or jogging;Yoga             With a group
# 6                       Walking or jogging                    Alone
# 7                       Walking or jogging                    Alone
# 8                           Gym;Team sport            With a friend
# 9                                      Gym            With a friend
# 10           Walking or jogging;Team sport             With a group
# 11                      Walking or jogging                    Alone
# 12                 I don't really exercise  I don't really exercise
# 13                      Walking or jogging                    Alone
# 14                      Walking or jogging                    Alone
#
#              Time Duration_of_time Healthy_diet  \
# 0   Early morning                0            2
# 1   Early morning                0            2
# 2   Early morning               30            2
# 3         Evening               60            1
# 4         Evening                0            1
# 5         Evening               60            2
# 6   Early morning               30            0
# 7   Early morning                0            2
# 8         Evening               60            0
# 9   Early morning               60            2
# 10  Early morning               60            1
# 11  Early morning              120            0
# 12        Evening                0            0
# 13        Evening               30            2
# 14        Evening               30            0
#
#                                  Healthy_diet_barrier  Healthy_score  \
# 0   Ease of access to fast food;Temptation and cra...              3
# 1   Ease of access to fast food;Temptation and cra...              4
# 2                             Temptation and cravings              4
# 3                             Temptation and cravings              4
# 4   Ease of access to fast food;Temptation and cra...              4
# 5                             Temptation and cravings              3
# 6                             Temptation and cravings              3
# 7                             Temptation and cravings              2
# 8                             Temptation and cravings              2
# 9                         Ease of access to fast food              3
# 10                                       Lack of time              4
# 11                            Temptation and cravings              4
# 12                            Temptation and cravings              1
# 13                            Temptation and cravings              3
# 14  Ease of access to fast food;Temptation and cra...              3
#
#    Recommend_friend Purchase_equipment  \
# 0                 1                  0
# 1                 1                  0
# 2                 1                  1
# 3                 1                  0
# 4                 1                  0
# 5                 1                  0
# 6                 0                  0
# 7                 1                  1
# 8                 1                  0
# 9                 1                  1
# 10                1                  1
# 11                1                  1
# 12                0                  0
# 13                0                  1
# 14                1                  1
#
#                                             Motivates
# 0   I'm sorry ... I'm not really interested in exe...
# 1   I want to be fit;I want to be flexible;I want ...
# 2                                    I want to be fit
# 3              I want to be fit;I want to lose weight
# 4                                    I want to be fit
# 5                               I want to be flexible
# 6                               I want to be flexible
# 7   I want to be fit;I'm sorry ... I'm not really ...
# 8   I want to be fit;I want to increase muscle mas...
# 9   I want to be fit;I want to lose weight;I want ...
# 10                                   I want to be fit
# 11  I want to be fit;I want to increase muscle mas...
# 12  I want to be fit;I want to increase muscle mas...
# 13             I want to be fit;I want to lose weight
# 14  I want to be fit;I want to increase muscle mas...
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 545 entries, 0 to 544
# Data columns (total 16 columns):
#  #   Column                Non-Null Count  Dtype
# ---  ------                --------------  -----
#  0   Gender                545 non-null    object
#  1   Age                   545 non-null    int64
#  2   Important_score       545 non-null    int64
#  3   Fitness_level         545 non-null    object
#  4   Exercise_frequency    545 non-null    int64
#  5   Exercise_barrier      545 non-null    object
#  6   Exercise_form         545 non-null    object
#  7   People_number         545 non-null    object
#  8   Time                  545 non-null    object
#  9   Duration_of_time      545 non-null    object
#  10  Healthy_diet          545 non-null    object
#  11  Healthy_diet_barrier  545 non-null    object
#  12  Healthy_score         545 non-null    int64
#  13  Recommend_friend      545 non-null    object
#  14  Purchase_equipment    545 non-null    object
#  15  Motivates             545 non-null    object
# dtypes: int64(4), object(12)
# memory usage: 68.2+ KB
# 數據已儲存!
# <ipython-input-1-4b948017c713>:13: FutureWarning: The default value of numeric_only in DataFrame.mean is deprecated. In a future version, it will default to False. In addition, specifying 'numeric_only=None' is deprecated. Select only valid columns or specify the value of numeric_only to silence this warning.
#   product_data = product_data.fillna(product_data.mean())
